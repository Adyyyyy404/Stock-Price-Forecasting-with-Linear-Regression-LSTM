# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')
df.head()
# Out:
# /tmp/ipython-input-603827078.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.288582  24.757336  23.848707  24.746228  212818400
# 2015-01-05  23.604328  24.137509  23.417716  24.057531  257142000
# 2015-01-06  23.606550  23.866475  23.244431  23.668754  263188400
# 2015-01-07  23.937574  24.037545  23.704307  23.815387  160423600
# 2015-01-08  24.857311  24.915073  24.148625  24.266371  237458000

# %%
df['Target'] = df['Close'].shift(-1)  # Next day's price

# Drop last row (NaN in target)
df.dropna(inplace=True)

X = df[['Close']]
y = df['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

preds = model.predict(X_test)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label="Actual Price")
plt.plot(preds, label="Predicted Price")
plt.title("Apple Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, preds)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 7.734073775929709

# %%
X = df[['Open', 'High', 'Low', 'Volume', 'Close']]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MAE:", mean_absolute_error(y_test, preds))
print("R² Score:", r2_score(y_test, preds))
# Out:
# MAE: 2.094686691779533
# R² Score: 0.9774756031224351

# %%
future = model.predict(X.tail(5))
print("Next 5 predicted prices:", future)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2424854483.py in <cell line: 0>()
# ----> 1 future = model.predict(X.tail(5))
#       2 print("Next 5 predicted prices:", future)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
#     278         if coef_.ndim == 1:
#
# ...

# %%
future = model.predict(df[['Close']].tail(5))
print("Next 5 predicted prices:", future)
# Out:
# Next 5 predicted prices: [193.39550867 192.32290507 191.77666525 191.87596909 192.3030443 ]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Define features and label
X = df[['Open', 'High', 'Low', 'Volume']]
y = df['Close']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict future
future = model.predict(X.tail(5)[['Open', 'High', 'Low', 'Volume']])
print("Next 5 predicted closing prices:", future)
# Out:
# Next 5 predicted closing prices: [[193.37939156]
#  [192.09492492]
#  [191.62778824]
#  [190.70021927]
#  [192.22364364]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test)

print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 0.8829121185738135
# Mean Absolute Error: 0.7421236194778831
# R² Score: 0.9974151338319225

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test.values, label='Actual Prices')
plt.plot(y_pred, label='Predicted Prices')
plt.title("Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
# !pip install tensorflow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Load dataset (replace with your own CSV if needed)
df = pd.read_csv('AAPL.csv')  # Example: Apple stock data
df = df[['Date', 'Close']]
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Scale data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# Create training and testing data
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size - 60:]  # overlap for continuity

# Function to create sequences
def create_dataset(data, sequence_length=60):
    x, y = [], []
    for i in range(sequence_length, len(data)):
        x.append(data[i - sequence_length:i, 0])
        y.append(data[i, 0])
    return np.array(x), np.array(y)

sequence_length = 60
x_train, y_train = create_dataset(train_data, sequence_length)
x_test, y_test = create_dataset(test_data, sequence_length)

# Reshape for LSTM input
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32)

# Predict
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(12,6))
plt.plot(actual, label='Actual Prices')
plt.plot(predictions, label='Predicted Prices')
plt.title('Stock Price Prediction with LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Print RMSE
rmse = np.sqrt(mean_squared_error(actual, predictions))
print("Root Mean Squared Error:", rmse)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3995780481.py in <cell line: 0>()
#       9
#      10 # Load dataset (replace with your own CSV if needed)
# ---> 11 df = pd.read_csv('AAPL.csv')  # Example: Apple stock data
#      12 df = df[['Date', 'Close']]
#      13 df['Date'] = pd.to_datetime(df['Date'])
#
# ...

# %%
# !pip install yfinance
# !pip install keras

import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
# Download Apple's stock price as an example
df = yf.download('AAPL', start='2015-01-01', end='2024-12-31')
df = df[['Close']]  # We’ll use only the closing price
df.head()
# Out:
# /tmp/ipython-input-3833272306.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', start='2015-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price           Close
# Ticker           AAPL
# Date
# 2015-01-02  24.288580
# 2015-01-05  23.604334
# 2015-01-06  23.606554
# 2015-01-07  23.937576
# 2015-01-08  24.857311

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Create sequences of 60 days of data
def create_sequences(data, seq_length=60):
    X = []
    y = []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data)

# Reshape to fit LSTM [samples, time_steps, features]
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(1))  # Output layer

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X, y, epochs=5, batch_size=32)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 14s 119ms/step - loss: 0.0352
# Epoch 2/5
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 3.8233e-04
# Epoch 3/5
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 3.5912e-04
# Epoch 4/5
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 3.6852e-04
# Epoch 5/5
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 3.3561e-04

# %%
# Use last 60 days to predict next day's price
last_60_days = scaled_data[-60:]
last_60_days = last_60_days.reshape((1, 60, 1))
predicted_price = model.predict(last_60_days)
predicted_price = scaler.inverse_transform(predicted_price)

print("Predicted Next Day Price:", predicted_price[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Predicted Next Day Price: 250.05699

# %%
plt.figure(figsize=(10, 5))
plt.plot(df.index[60:], scaler.inverse_transform(y.reshape(-1, 1)), label="Actual")
plt.plot(df.index[60:], scaler.inverse_transform(model.predict(X)), label="Predicted")
plt.title("LSTM Stock Price Prediction")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step

# %%
import numpy as np

def create_dataset(data, time_step=60):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close']].values)

# Create sequences
time_step = 60
X, y = create_dataset(scaled_data, time_step)

# %%
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Build the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))  # Output layer

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X, y, epochs=10, batch_size=64, validation_split=0.1)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - loss: 0.0486 - val_loss: 0.0011
# Epoch 2/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 3/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 4/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0014 - val_loss: 9.5857e-04
# Epoch 5/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 6/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 7/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0013 - val_loss: 8.8510e-04
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Training & Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Fetch historical stock data (e.g., Apple Inc.)
ticker = 'AAPL'  # You can change this to any stock symbol (e.g., TSLA, MSFT, INFY.NS)
df = yf.download(ticker, start='2015-01-01', end='2024-12-31')

# Keep only 'Close' price
df = df[['Close']]
df = df.reset_index()  # Reset index to get 'Date' as a column if needed
df.head()
# Out:
# /tmp/ipython-input-118050135.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start='2015-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close
# Ticker                  AAPL
# 0      2015-01-02  24.288580
# 1      2015-01-05  23.604334
# 2      2015-01-06  23.606554
# 3      2015-01-07  23.937576
# 4      2015-01-08  24.857311

# %%
# Download last 60 days of data
recent_df = yf.download(ticker, period='60d', interval='1d')
recent_df = recent_df[['Close']]
recent_df.tail()
# Out:
# /tmp/ipython-input-2613407174.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   recent_df = yf.download(ticker, period='60d', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price            Close
# Ticker            AAPL
# Date
# 2025-07-24  213.759995
# 2025-07-25  213.880005
# 2025-07-28  214.050003
# 2025-07-29  211.270004
# 2025-07-30  209.050003

# %%
pd.read_csv("AAPL.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2084387805.py in <cell line: 0>()
# ----> 1 pd.read_csv("AAPL.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
import yfinance as yf
import pandas as pd

# Step 1: Fetch data from Yahoo Finance
df = yf.download('AAPL', start='2015-01-01', end='2024-12-31')

# Step 2: Keep only the 'Close' price
df = df[['Close']]

# Optional: Reset index to get Date column
df.reset_index(inplace=True)

# Preview
df.head()
# Out:
# /tmp/ipython-input-1300091648.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', start='2015-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close
# Ticker                  AAPL
# 0      2015-01-02  24.288580
# 1      2015-01-05  23.604334
# 2      2015-01-06  23.606554
# 3      2015-01-07  23.937576
# 4      2015-01-08  24.857311

# %%
import yfinance as yf
import pandas as pd

# Fetch recent 60 days of data for a stock (e.g., Apple)
ticker = 'AAPL'
real_time_data = yf.download(ticker, period='60d', interval='1d')

# Only use the 'Close' column
real_time_data = real_time_data[['Close']]
real_time_data.reset_index(inplace=True)

# Preview
print(real_time_data.tail())
# Out:
# /tmp/ipython-input-4200652093.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   real_time_data = yf.download(ticker, period='60d', interval='1d')
# [*********************100%***********************]  1 of 1 completed
# Price        Date       Close
# Ticker                   AAPL
# 55     2025-07-24  213.759995
# 56     2025-07-25  213.880005
# 57     2025-07-28  214.050003
# 58     2025-07-29  211.270004
# 59     2025-07-30  209.050003

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# streamlit_app.py
import streamlit as st
import yfinance as yf
import matplotlib.pyplot as plt

st.title("📈 Stock Price Viewer")

ticker = st.text_input("Enter stock symbol (e.g., AAPL, TSLA, INFY)", "AAPL")

if ticker:
    data = yf.download(ticker, period="1y")
    st.write(f"Showing 1-year closing prices for {ticker}")
    st.line_chart(data["Close"])

    st.write("Last 5 Days")
    st.dataframe(data.tail(5))
# Out:
# 2025-07-30 22:37:13.455 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:37:13.808
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-07-30 22:37:13.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:37:13.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:37:13.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:37:13.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:37:13.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# streamlit_app.py
import streamlit as st
import yfinance as yf
import matplotlib.pyplot as plt

st.title("📈 Stock Price Viewer")

ticker = st.text_input("Enter stock symbol (e.g., AAPL, TSLA, INFY)", "AAPL")

if ticker:
    data = yf.download(ticker, period="1y")
    st.write(f"Showing 1-year closing prices for {ticker}")
    st.line_chart(data["Close"])

    st.write("Last 5 Days")
    st.dataframe(data.tail(5))
# Out:
# 2025-07-30 22:40:49.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-30 22:40:49.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
streamlit run streamlit_app.py
# Out:
#   File "/tmp/ipython-input-2482160671.py", line 1
#     streamlit run streamlit_app.py
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install streamlit pyngrok

# %%
# %%writefile streamlit_app.py
# Paste your Streamlit code here
# streamlit_app.py
import streamlit as st
import yfinance as yf
import matplotlib.pyplot as plt

st.title("📈 Stock Price Viewer")

ticker = st.text_input("Enter stock symbol (e.g., AAPL, TSLA, INFY)", "AAPL")

if ticker:
    data = yf.download(ticker, period="1y")
    st.write(f"Showing 1-year closing prices for {ticker}")
    st.line_chart(data["Close"])

    st.write("Last 5 Days")
    st.dataframe(data.tail(5))
# Out:
# Overwriting streamlit_app.py

# %%
from pyngrok import ngrok

# Run the Streamlit app in the background
# !streamlit run streamlit_app.py &

# Open a tunnel to the Streamlit app
public_url = ngrok.connect(port=8501)
print("Streamlit App URL:", public_url)
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.234.167.11:8501
#
#   Stopping...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1503264896.py in <cell line: 0>()
#       5
#       6 # Open a tunnel to the Streamlit app
# ----> 7 public_url = ngrok.connect(port=8501)
#       8 print("Streamlit App URL:", public_url)
#
# /usr/local/lib/python3.11/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     383     logger.info(f"Opening tunnel named: {name}")
#     384
# --> 385     api_url = get_ngrok_process(pyngrok_config).api_url
#     386
#     387     logger.debug(f"Creating tunnel with options: {options}")
#
# ...
